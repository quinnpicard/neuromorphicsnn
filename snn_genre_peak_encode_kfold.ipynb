# %%
import librosa
import neuro
import random
import numpy as np
import pandas as pd
import risp
import eons
import json
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score
from sklearn.model_selection import KFold
import wave
import os 
from scipy.signal import find_peaks


# original params
if False:
    eo_params = {
        "starting_nodes": 3,
        "starting_edges": 6,
        "merge_rate": 0,
        "population_size": 100,
        "multi_edges": 0,
        "crossover_rate": 0.5,
        "mutation_rate": 0.9,
        "selection_type": "tournament",
        "tournament_size_factor": 0.1,
        "tournament_best_net_factor": 0.9,
        "random_factor": 0.05,
        "num_mutations": 3,
        "node_mutations": { "Threshold": 1.0 },
        "net_mutations": { },
        "edge_mutations": { "Weight": 0.5, "Delay": 0.5 },
        "num_best" : 4
    }

eo_params = {
    "merge_rate": 0.1,
    "population_size": 100,
    "multi_edges": 0,
    "crossover_rate": 0.5,
    "mutation_rate": 0.8,
    "selection_type": "tournament",
    "tournament_size_factor": 0.1,
    "tournament_best_net_factor": 0.9,
    "random_factor": 0.05,
    "num_mutations": 4,
    "node_mutations": { "Threshold": 1.0 },
    "net_mutations": { },
    "edge_mutations": { "Weight": 0.5, "Delay": 0.5 },
    "num_best" : 4
}

# %%
import wave
import librosa
import numpy as np
import os 
from scipy.signal import find_peaks

unique_sample_rates = np.array([])
min_song_len = float('inf')

directory = 'audio_database'


def mel_binary_mean(mel_spectrum):
    # Computes the row-wise mean values (the mean of each channel)
    channel_means = np.mean(mel_spectrum, axis=1)

    # Applies thresholding to create binary representation
    binary_spectrum = np.where(mel_spectrum >= channel_means[:, np.newaxis], 1, 0)

    return binary_spectrum


def find_peaks_per_channel(spectrum, threshold=0):
    peaks = np.zeros_like(spectrum)
    
    for i in range(spectrum.shape[0]):
        channel_data = spectrum[i, :]
        channel_peaks, _ = find_peaks(channel_data, height=threshold)
        peaks[i, channel_peaks] = 1
    
    return peaks

# Create a new folder to save the npy files
new_folder = "npy_files"
new_folder_path = os.path.join(directory, new_folder)
os.makedirs(new_folder_path, exist_ok=True)

for folder_name in os.listdir(directory):
    unique_song_len = np.array([])

    folder_path = os.path.join(directory, folder_name)
    if os.path.isdir(folder_path):  # Check if the item is a directory
        for filename in os.listdir(folder_path):
            if filename.endswith('.wav'):
                try: 
                    file_path = os.path.join(folder_path, filename)
                    audio_signal, sample_rate = librosa.load(file_path, sr=None)

                    unique_sample_rates = np.append(unique_sample_rates, sample_rate)
                    
                    n_fft = 2048
                    hop_length = n_fft // 16
                    magnitude_spectrum = np.abs(librosa.stft(audio_signal, n_fft=n_fft, hop_length=hop_length))
                    num_mels = 8
                    mel_spectrum = librosa.feature.melspectrogram(
                        sr=sample_rate,
                        S=magnitude_spectrum,
                        n_fft=n_fft,
                        hop_length=hop_length,
                        n_mels=num_mels
                    )
                    #mel_spectrum = mel_spectrum[:, :min_song_len]
                    unique_song_len = np.append(unique_song_len, np.shape(mel_spectrum[0]))
                    peak_spectrogram = mel_binary_mean(mel_spectrum) #<---------- to change encoder 
                    #peak_spectrogram = peak_spectrogram[:, :min_song_len]

                    output_filename = f"{filename}_peak_spectrogram.npy"  # Move this line here
                    output_path = os.path.join(new_folder_path, output_filename)
                    np.save(output_path, peak_spectrogram)
                    print(f"Processed {filename} in folder {folder_name}. Saved peak_spectrogram as {output_filename}")
                    
                    
                    if min_song_len > len(peak_spectrogram[1]):
                        min_song_len = len(peak_spectrogram[1])

                except Exception as e:
                    print(f"Error processing {filename} in folder {folder_name}: {str(e)}")
                    continue
        print(f"unique song length in {folder_name} is {np.unique(unique_song_len)}")

min_song_len = int(min_song_len)        
print(f"unique sample rates for all genres {np.unique(unique_sample_rates)}")
print(f"minimum song length is {min_song_len}")
# Out:
# Processed pop.00027.wav in folder pop. Saved peak_spectrogram as pop.00027.wav_peak_spectrogram.npy
# Processed pop.00033.wav in folder pop. Saved peak_spectrogram as pop.00033.wav_peak_spectrogram.npy
# Processed pop.00032.wav in folder pop. Saved peak_spectrogram as pop.00032.wav_peak_spectrogram.npy
# Processed pop.00026.wav in folder pop. Saved peak_spectrogram as pop.00026.wav_peak_spectrogram.npy
# Processed pop.00030.wav in folder pop. Saved peak_spectrogram as pop.00030.wav_peak_spectrogram.npy
# Processed pop.00024.wav in folder pop. Saved peak_spectrogram as pop.00024.wav_peak_spectrogram.npy
# Processed pop.00018.wav in folder pop. Saved peak_spectrogram as pop.00018.wav_peak_spectrogram.npy
# Processed pop.00019.wav in folder pop. Saved peak_spectrogram as pop.00019.wav_peak_spectrogram.npy
# Processed pop.00025.wav in folder pop. Saved peak_spectrogram as pop.00025.wav_peak_spectrogram.npy
# Processed pop.00031.wav in folder pop. Saved peak_spectrogram as pop.00031.wav_peak_spectrogram.npy
# Processed pop.00009.wav in folder pop. Saved peak_spectrogram as pop.00009.wav_peak_spectrogram.npy
# Processed pop.00035.wav in folder pop. Saved peak_spectrogram as pop.00035.wav_peak_spectrogram.npy
# Processed pop.00021.wav in folder pop. Saved peak_spectrogram as pop.00021.wav_peak_spectrogram.npy
# Processed pop.00020.wav in folder pop. Saved peak_spectrogram as pop.00020.wav_peak_spectrogram.npy
# Processed pop.00034.wav in folder pop. Saved peak_spectrogram as pop.00034.wav_peak_spectrogram.npy
# Processed pop.00008.wav in folder pop. Saved peak_spectrogram as pop.00008.wav_peak_spectrogram.npy
# Processed pop.00022.wav in folder pop. Saved peak_spectrogram as pop.00022.wav_peak_spectrogram.npy
# Processed pop.00036.wav in folder pop. Saved peak_spectrogram as pop.00036.wav_peak_spectrogram.npy
# Processed pop.00037.wav in folder pop. Saved peak_spectrogram as pop.00037.wav_peak_spectrogram.npy
# Processed pop.00023.wav in folder pop. Saved peak_spectrogram as pop.00023.wav_peak_spectrogram.npy
# Processed pop.00044.wav in folder pop. Saved peak_spectrogram as pop.00044.wav_peak_spectrogram.npy
# Processed pop.00050.wav in folder pop. Saved peak_spectrogram as pop.00050.wav_peak_spectrogram.npy
# Processed pop.00078.wav in folder pop. Saved peak_spectrogram as pop.00078.wav_peak_spectrogram.npy
# Processed pop.00087.wav in folder pop. Saved peak_spectrogram as pop.00087.wav_peak_spectrogram.npy
# Processed pop.00093.wav in folder pop. Saved peak_spectrogram as pop.00093.wav_peak_spectrogram.npy
# Processed pop.00092.wav in folder pop. Saved peak_spectrogram as pop.00092.wav_peak_spectrogram.npy
# Processed pop.00086.wav in folder pop. Saved peak_spectrogram as pop.00086.wav_peak_spectrogram.npy
# Processed pop.00079.wav in folder pop. Saved peak_spectrogram as pop.00079.wav_peak_spectrogram.npy
# Processed pop.00051.wav in folder pop. Saved peak_spectrogram as pop.00051.wav_peak_spectrogram.npy
# Processed pop.00045.wav in folder pop. Saved peak_spectrogram as pop.00045.wav_peak_spectrogram.npy
# Processed pop.00053.wav in folder pop. Saved peak_spectrogram as pop.00053.wav_peak_spectrogram.npy
# Processed pop.00047.wav in folder pop. Saved peak_spectrogram as pop.00047.wav_peak_spectrogram.npy
# Processed pop.00090.wav in folder pop. Saved peak_spectrogram as pop.00090.wav_peak_spectrogram.npy
# Processed pop.00084.wav in folder pop. Saved peak_spectrogram as pop.00084.wav_peak_spectrogram.npy
# Processed pop.00085.wav in folder pop. Saved peak_spectrogram as pop.00085.wav_peak_spectrogram.npy
# Processed pop.00091.wav in folder pop. Saved peak_spectrogram as pop.00091.wav_peak_spectrogram.npy
# Processed pop.00046.wav in folder pop. Saved peak_spectrogram as pop.00046.wav_peak_spectrogram.npy
# Processed pop.00052.wav in folder pop. Saved peak_spectrogram as pop.00052.wav_peak_spectrogram.npy
# Processed pop.00056.wav in folder pop. Saved peak_spectrogram as pop.00056.wav_peak_spectrogram.npy
# Processed pop.00042.wav in folder pop. Saved peak_spectrogram as pop.00042.wav_peak_spectrogram.npy
# Processed pop.00095.wav in folder pop. Saved peak_spectrogram as pop.00095.wav_peak_spectrogram.npy
# Processed pop.00081.wav in folder pop. Saved peak_spectrogram as pop.00081.wav_peak_spectrogram.npy
# Processed pop.00080.wav in folder pop. Saved peak_spectrogram as pop.00080.wav_peak_spectrogram.npy
# Processed pop.00094.wav in folder pop. Saved peak_spectrogram as pop.00094.wav_peak_spectrogram.npy
# Processed pop.00043.wav in folder pop. Saved peak_spectrogram as pop.00043.wav_peak_spectrogram.npy
# Processed pop.00057.wav in folder pop. Saved peak_spectrogram as pop.00057.wav_peak_spectrogram.npy
# Processed pop.00069.wav in folder pop. Saved peak_spectrogram as pop.00069.wav_peak_spectrogram.npy
# Processed pop.00041.wav in folder pop. Saved peak_spectrogram as pop.00041.wav_peak_spectrogram.npy
# Processed pop.00055.wav in folder pop. Saved peak_spectrogram as pop.00055.wav_peak_spectrogram.npy
# Processed pop.00082.wav in folder pop. Saved peak_spectrogram as pop.00082.wav_peak_spectrogram.npy
# Processed pop.00096.wav in folder pop. Saved peak_spectrogram as pop.00096.wav_peak_spectrogram.npy
# Processed pop.00097.wav in folder pop. Saved peak_spectrogram as pop.00097.wav_peak_spectrogram.npy
# Processed pop.00083.wav in folder pop. Saved peak_spectrogram as pop.00083.wav_peak_spectrogram.npy
# Processed pop.00054.wav in folder pop. Saved peak_spectrogram as pop.00054.wav_peak_spectrogram.npy
# Processed pop.00040.wav in folder pop. Saved peak_spectrogram as pop.00040.wav_peak_spectrogram.npy
# Processed pop.00068.wav in folder pop. Saved peak_spectrogram as pop.00068.wav_peak_spectrogram.npy
# Processed pop.00065.wav in folder pop. Saved peak_spectrogram as pop.00065.wav_peak_spectrogram.npy
# Processed pop.00071.wav in folder pop. Saved peak_spectrogram as pop.00071.wav_peak_spectrogram.npy
# Processed pop.00059.wav in folder pop. Saved peak_spectrogram as pop.00059.wav_peak_spectrogram.npy
# Processed pop.00058.wav in folder pop. Saved peak_spectrogram as pop.00058.wav_peak_spectrogram.npy
# Processed pop.00070.wav in folder pop. Saved peak_spectrogram as pop.00070.wav_peak_spectrogram.npy
# Processed pop.00064.wav in folder pop. Saved peak_spectrogram as pop.00064.wav_peak_spectrogram.npy
# Processed pop.00072.wav in folder pop. Saved peak_spectrogram as pop.00072.wav_peak_spectrogram.npy
# Processed pop.00066.wav in folder pop. Saved peak_spectrogram as pop.00066.wav_peak_spectrogram.npy
# Processed pop.00099.wav in folder pop. Saved peak_spectrogram as pop.00099.wav_peak_spectrogram.npy
# Processed pop.00098.wav in folder pop. Saved peak_spectrogram as pop.00098.wav_peak_spectrogram.npy
# Processed pop.00067.wav in folder pop. Saved peak_spectrogram as pop.00067.wav_peak_spectrogram.npy
# Processed pop.00073.wav in folder pop. Saved peak_spectrogram as pop.00073.wav_peak_spectrogram.npy
# Processed pop.00077.wav in folder pop. Saved peak_spectrogram as pop.00077.wav_peak_spectrogram.npy
# Processed pop.00063.wav in folder pop. Saved peak_spectrogram as pop.00063.wav_peak_spectrogram.npy
# Processed pop.00088.wav in folder pop. Saved peak_spectrogram as pop.00088.wav_peak_spectrogram.npy
# Processed pop.00089.wav in folder pop. Saved peak_spectrogram as pop.00089.wav_peak_spectrogram.npy
# Processed pop.00062.wav in folder pop. Saved peak_spectrogram as pop.00062.wav_peak_spectrogram.npy
# Processed pop.00076.wav in folder pop. Saved peak_spectrogram as pop.00076.wav_peak_spectrogram.npy
# Processed pop.00048.wav in folder pop. Saved peak_spectrogram as pop.00048.wav_peak_spectrogram.npy
# Processed pop.00060.wav in folder pop. Saved peak_spectrogram as pop.00060.wav_peak_spectrogram.npy
# Processed pop.00074.wav in folder pop. Saved peak_spectrogram as pop.00074.wav_peak_spectrogram.npy
# Processed pop.00075.wav in folder pop. Saved peak_spectrogram as pop.00075.wav_peak_spectrogram.npy
# Processed pop.00061.wav in folder pop. Saved peak_spectrogram as pop.00061.wav_peak_spectrogram.npy
# Processed pop.00049.wav in folder pop. Saved peak_spectrogram as pop.00049.wav_peak_spectrogram.npy
# Processed pop.00006.wav in folder pop. Saved peak_spectrogram as pop.00006.wav_peak_spectrogram.npy
# Processed pop.00012.wav in folder pop. Saved peak_spectrogram as pop.00012.wav_peak_spectrogram.npy
# Processed pop.00013.wav in folder pop. Saved peak_spectrogram as pop.00013.wav_peak_spectrogram.npy
# Processed pop.00007.wav in folder pop. Saved peak_spectrogram as pop.00007.wav_peak_spectrogram.npy
# Processed pop.00011.wav in folder pop. Saved peak_spectrogram as pop.00011.wav_peak_spectrogram.npy
# Processed pop.00005.wav in folder pop. Saved peak_spectrogram as pop.00005.wav_peak_spectrogram.npy
# Processed pop.00039.wav in folder pop. Saved peak_spectrogram as pop.00039.wav_peak_spectrogram.npy
# Processed pop.00038.wav in folder pop. Saved peak_spectrogram as pop.00038.wav_peak_spectrogram.npy
# Processed pop.00004.wav in folder pop. Saved peak_spectrogram as pop.00004.wav_peak_spectrogram.npy
# Processed pop.00010.wav in folder pop. Saved peak_spectrogram as pop.00010.wav_peak_spectrogram.npy
# Processed pop.00028.wav in folder pop. Saved peak_spectrogram as pop.00028.wav_peak_spectrogram.npy
# Processed pop.00014.wav in folder pop. Saved peak_spectrogram as pop.00014.wav_peak_spectrogram.npy
# Processed pop.00000.wav in folder pop. Saved peak_spectrogram as pop.00000.wav_peak_spectrogram.npy
# Processed pop.00001.wav in folder pop. Saved peak_spectrogram as pop.00001.wav_peak_spectrogram.npy
# Processed pop.00015.wav in folder pop. Saved peak_spectrogram as pop.00015.wav_peak_spectrogram.npy
# Processed pop.00029.wav in folder pop. Saved peak_spectrogram as pop.00029.wav_peak_spectrogram.npy
# Processed pop.00003.wav in folder pop. Saved peak_spectrogram as pop.00003.wav_peak_spectrogram.npy
# Processed pop.00017.wav in folder pop. Saved peak_spectrogram as pop.00017.wav_peak_spectrogram.npy
# Processed pop.00016.wav in folder pop. Saved peak_spectrogram as pop.00016.wav_peak_spectrogram.npy
# Processed pop.00002.wav in folder pop. Saved peak_spectrogram as pop.00002.wav_peak_spectrogram.npy
# unique song length in pop is [5169.]
# Processed metal.00022.wav in folder metal. Saved peak_spectrogram as metal.00022.wav_peak_spectrogram.npy
# Processed metal.00036.wav in folder metal. Saved peak_spectrogram as metal.00036.wav_peak_spectrogram.npy
# Processed metal.00037.wav in folder metal. Saved peak_spectrogram as metal.00037.wav_peak_spectrogram.npy
# Processed metal.00023.wav in folder metal. Saved peak_spectrogram as metal.00023.wav_peak_spectrogram.npy
# Processed metal.00009.wav in folder metal. Saved peak_spectrogram as metal.00009.wav_peak_spectrogram.npy
# Processed metal.00035.wav in folder metal. Saved peak_spectrogram as metal.00035.wav_peak_spectrogram.npy
# Processed metal.00021.wav in folder metal. Saved peak_spectrogram as metal.00021.wav_peak_spectrogram.npy
# Processed metal.00020.wav in folder metal. Saved peak_spectrogram as metal.00020.wav_peak_spectrogram.npy
# Processed metal.00034.wav in folder metal. Saved peak_spectrogram as metal.00034.wav_peak_spectrogram.npy
# Processed metal.00008.wav in folder metal. Saved peak_spectrogram as metal.00008.wav_peak_spectrogram.npy
# Processed metal.00030.wav in folder metal. Saved peak_spectrogram as metal.00030.wav_peak_spectrogram.npy
# Processed metal.00024.wav in folder metal. Saved peak_spectrogram as metal.00024.wav_peak_spectrogram.npy
# Processed metal.00018.wav in folder metal. Saved peak_spectrogram as metal.00018.wav_peak_spectrogram.npy
# Processed metal.00019.wav in folder metal. Saved peak_spectrogram as metal.00019.wav_peak_spectrogram.npy
# Processed metal.00025.wav in folder metal. Saved peak_spectrogram as metal.00025.wav_peak_spectrogram.npy
# Processed metal.00031.wav in folder metal. Saved peak_spectrogram as metal.00031.wav_peak_spectrogram.npy
# Processed metal.00027.wav in folder metal. Saved peak_spectrogram as metal.00027.wav_peak_spectrogram.npy
# Processed metal.00033.wav in folder metal. Saved peak_spectrogram as metal.00033.wav_peak_spectrogram.npy
# Processed metal.00032.wav in folder metal. Saved peak_spectrogram as metal.00032.wav_peak_spectrogram.npy
# Processed metal.00026.wav in folder metal. Saved peak_spectrogram as metal.00026.wav_peak_spectrogram.npy
# Processed metal.00082.wav in folder metal. Saved peak_spectrogram as metal.00082.wav_peak_spectrogram.npy
# Processed metal.00096.wav in folder metal. Saved peak_spectrogram as metal.00096.wav_peak_spectrogram.npy
# Processed metal.00069.wav in folder metal. Saved peak_spectrogram as metal.00069.wav_peak_spectrogram.npy
# Processed metal.00041.wav in folder metal. Saved peak_spectrogram as metal.00041.wav_peak_spectrogram.npy
# Processed metal.00055.wav in folder metal. Saved peak_spectrogram as metal.00055.wav_peak_spectrogram.npy
# Processed metal.00054.wav in folder metal. Saved peak_spectrogram as metal.00054.wav_peak_spectrogram.npy
# Processed metal.00040.wav in folder metal. Saved peak_spectrogram as metal.00040.wav_peak_spectrogram.npy
# Processed metal.00068.wav in folder metal. Saved peak_spectrogram as metal.00068.wav_peak_spectrogram.npy
# Processed metal.00097.wav in folder metal. Saved peak_spectrogram as metal.00097.wav_peak_spectrogram.npy
# Processed metal.00083.wav in folder metal. Saved peak_spectrogram as metal.00083.wav_peak_spectrogram.npy
# Processed metal.00095.wav in folder metal. Saved peak_spectrogram as metal.00095.wav_peak_spectrogram.npy
# Processed metal.00081.wav in folder metal. Saved peak_spectrogram as metal.00081.wav_peak_spectrogram.npy
# Processed metal.00056.wav in folder metal. Saved peak_spectrogram as metal.00056.wav_peak_spectrogram.npy
# Processed metal.00042.wav in folder metal. Saved peak_spectrogram as metal.00042.wav_peak_spectrogram.npy
# Processed metal.00043.wav in folder metal. Saved peak_spectrogram as metal.00043.wav_peak_spectrogram.npy
# Processed metal.00057.wav in folder metal. Saved peak_spectrogram as metal.00057.wav_peak_spectrogram.npy
# Processed metal.00080.wav in folder metal. Saved peak_spectrogram as metal.00080.wav_peak_spectrogram.npy
# Processed metal.00094.wav in folder metal. Saved peak_spectrogram as metal.00094.wav_peak_spectrogram.npy
# Processed metal.00090.wav in folder metal. Saved peak_spectrogram as metal.00090.wav_peak_spectrogram.npy
# Processed metal.00084.wav in folder metal. Saved peak_spectrogram as metal.00084.wav_peak_spectrogram.npy
# Processed metal.00053.wav in folder metal. Saved peak_spectrogram as metal.00053.wav_peak_spectrogram.npy
# Processed metal.00047.wav in folder metal. Saved peak_spectrogram as metal.00047.wav_peak_spectrogram.npy
# Processed metal.00046.wav in folder metal. Saved peak_spectrogram as metal.00046.wav_peak_spectrogram.npy
# Processed metal.00052.wav in folder metal. Saved peak_spectrogram as metal.00052.wav_peak_spectrogram.npy
# Processed metal.00085.wav in folder metal. Saved peak_spectrogram as metal.00085.wav_peak_spectrogram.npy
# Processed metal.00091.wav in folder metal. Saved peak_spectrogram as metal.00091.wav_peak_spectrogram.npy
# Processed metal.00087.wav in folder metal. Saved peak_spectrogram as metal.00087.wav_peak_spectrogram.npy
# Processed metal.00093.wav in folder metal. Saved peak_spectrogram as metal.00093.wav_peak_spectrogram.npy
# Processed metal.00044.wav in folder metal. Saved peak_spectrogram as metal.00044.wav_peak_spectrogram.npy
# Processed metal.00050.wav in folder metal. Saved peak_spectrogram as metal.00050.wav_peak_spectrogram.npy
# Processed metal.00078.wav in folder metal. Saved peak_spectrogram as metal.00078.wav_peak_spectrogram.npy
# Processed metal.00079.wav in folder metal. Saved peak_spectrogram as metal.00079.wav_peak_spectrogram.npy
# Processed metal.00051.wav in folder metal. Saved peak_spectrogram as metal.00051.wav_peak_spectrogram.npy
# Processed metal.00045.wav in folder metal. Saved peak_spectrogram as metal.00045.wav_peak_spectrogram.npy
# Processed metal.00092.wav in folder metal. Saved peak_spectrogram as metal.00092.wav_peak_spectrogram.npy
# Processed metal.00086.wav in folder metal. Saved peak_spectrogram as metal.00086.wav_peak_spectrogram.npy
# Processed metal.00048.wav in folder metal. Saved peak_spectrogram as metal.00048.wav_peak_spectrogram.npy
# Processed metal.00060.wav in folder metal. Saved peak_spectrogram as metal.00060.wav_peak_spectrogram.npy
# Processed metal.00074.wav in folder metal. Saved peak_spectrogram as metal.00074.wav_peak_spectrogram.npy
# Processed metal.00075.wav in folder metal. Saved peak_spectrogram as metal.00075.wav_peak_spectrogram.npy
# Processed metal.00061.wav in folder metal. Saved peak_spectrogram as metal.00061.wav_peak_spectrogram.npy
# Processed metal.00049.wav in folder metal. Saved peak_spectrogram as metal.00049.wav_peak_spectrogram.npy
# Processed metal.00088.wav in folder metal. Saved peak_spectrogram as metal.00088.wav_peak_spectrogram.npy
# Processed metal.00077.wav in folder metal. Saved peak_spectrogram as metal.00077.wav_peak_spectrogram.npy
# Processed metal.00063.wav in folder metal. Saved peak_spectrogram as metal.00063.wav_peak_spectrogram.npy
# Processed metal.00062.wav in folder metal. Saved peak_spectrogram as metal.00062.wav_peak_spectrogram.npy
# Processed metal.00076.wav in folder metal. Saved peak_spectrogram as metal.00076.wav_peak_spectrogram.npy
# Processed metal.00089.wav in folder metal. Saved peak_spectrogram as metal.00089.wav_peak_spectrogram.npy
# Processed metal.00099.wav in folder metal. Saved peak_spectrogram as metal.00099.wav_peak_spectrogram.npy
# Processed metal.00072.wav in folder metal. Saved peak_spectrogram as metal.00072.wav_peak_spectrogram.npy
# Processed metal.00066.wav in folder metal. Saved peak_spectrogram as metal.00066.wav_peak_spectrogram.npy
# Processed metal.00067.wav in folder metal. Saved peak_spectrogram as metal.00067.wav_peak_spectrogram.npy
# Processed metal.00073.wav in folder metal. Saved peak_spectrogram as metal.00073.wav_peak_spectrogram.npy
# Processed metal.00098.wav in folder metal. Saved peak_spectrogram as metal.00098.wav_peak_spectrogram.npy
# Processed metal.00065.wav in folder metal. Saved peak_spectrogram as metal.00065.wav_peak_spectrogram.npy
# Processed metal.00071.wav in folder metal. Saved peak_spectrogram as metal.00071.wav_peak_spectrogram.npy
# Processed metal.00059.wav in folder metal. Saved peak_spectrogram as metal.00059.wav_peak_spectrogram.npy
# Processed metal.00058.wav in folder metal. Saved peak_spectrogram as metal.00058.wav_peak_spectrogram.npy
# Processed metal.00070.wav in folder metal. Saved peak_spectrogram as metal.00070.wav_peak_spectrogram.npy
# Processed metal.00064.wav in folder metal. Saved peak_spectrogram as metal.00064.wav_peak_spectrogram.npy
# Processed metal.00003.wav in folder metal. Saved peak_spectrogram as metal.00003.wav_peak_spectrogram.npy
# Processed metal.00017.wav in folder metal. Saved peak_spectrogram as metal.00017.wav_peak_spectrogram.npy
# Processed metal.00016.wav in folder metal. Saved peak_spectrogram as metal.00016.wav_peak_spectrogram.npy
# Processed metal.00002.wav in folder metal. Saved peak_spectrogram as metal.00002.wav_peak_spectrogram.npy
# Processed metal.00028.wav in folder metal. Saved peak_spectrogram as metal.00028.wav_peak_spectrogram.npy
# Processed metal.00014.wav in folder metal. Saved peak_spectrogram as metal.00014.wav_peak_spectrogram.npy
# Processed metal.00000.wav in folder metal. Saved peak_spectrogram as metal.00000.wav_peak_spectrogram.npy
# Processed metal.00001.wav in folder metal. Saved peak_spectrogram as metal.00001.wav_peak_spectrogram.npy
# Processed metal.00015.wav in folder metal. Saved peak_spectrogram as metal.00015.wav_peak_spectrogram.npy
# Processed metal.00029.wav in folder metal. Saved peak_spectrogram as metal.00029.wav_peak_spectrogram.npy
# Processed metal.00011.wav in folder metal. Saved peak_spectrogram as metal.00011.wav_peak_spectrogram.npy
# Processed metal.00005.wav in folder metal. Saved peak_spectrogram as metal.00005.wav_peak_spectrogram.npy
# Processed metal.00039.wav in folder metal. Saved peak_spectrogram as metal.00039.wav_peak_spectrogram.npy
# Processed metal.00038.wav in folder metal. Saved peak_spectrogram as metal.00038.wav_peak_spectrogram.npy
# Processed metal.00004.wav in folder metal. Saved peak_spectrogram as metal.00004.wav_peak_spectrogram.npy
# Processed metal.00010.wav in folder metal. Saved peak_spectrogram as metal.00010.wav_peak_spectrogram.npy
# Processed metal.00006.wav in folder metal. Saved peak_spectrogram as metal.00006.wav_peak_spectrogram.npy
# Processed metal.00012.wav in folder metal. Saved peak_spectrogram as metal.00012.wav_peak_spectrogram.npy
# Processed metal.00013.wav in folder metal. Saved peak_spectrogram as metal.00013.wav_peak_spectrogram.npy
# Processed metal.00007.wav in folder metal. Saved peak_spectrogram as metal.00007.wav_peak_spectrogram.npy
# unique song length in metal is [5169. 5171.]
# Processed disco.00052.wav in folder disco. Saved peak_spectrogram as disco.00052.wav_peak_spectrogram.npy
# Processed disco.00046.wav in folder disco. Saved peak_spectrogram as disco.00046.wav_peak_spectrogram.npy
# Processed disco.00091.wav in folder disco. Saved peak_spectrogram as disco.00091.wav_peak_spectrogram.npy
# Processed disco.00085.wav in folder disco. Saved peak_spectrogram as disco.00085.wav_peak_spectrogram.npy
# Processed disco.00084.wav in folder disco. Saved peak_spectrogram as disco.00084.wav_peak_spectrogram.npy
# Processed disco.00090.wav in folder disco. Saved peak_spectrogram as disco.00090.wav_peak_spectrogram.npy
# Processed disco.00047.wav in folder disco. Saved peak_spectrogram as disco.00047.wav_peak_spectrogram.npy
# Processed disco.00053.wav in folder disco. Saved peak_spectrogram as disco.00053.wav_peak_spectrogram.npy
# Processed disco.00045.wav in folder disco. Saved peak_spectrogram as disco.00045.wav_peak_spectrogram.npy
# Processed disco.00051.wav in folder disco. Saved peak_spectrogram as disco.00051.wav_peak_spectrogram.npy
# Processed disco.00079.wav in folder disco. Saved peak_spectrogram as disco.00079.wav_peak_spectrogram.npy
# Processed disco.00086.wav in folder disco. Saved peak_spectrogram as disco.00086.wav_peak_spectrogram.npy
# Processed disco.00092.wav in folder disco. Saved peak_spectrogram as disco.00092.wav_peak_spectrogram.npy
# Processed disco.00093.wav in folder disco. Saved peak_spectrogram as disco.00093.wav_peak_spectrogram.npy
# Processed disco.00087.wav in folder disco. Saved peak_spectrogram as disco.00087.wav_peak_spectrogram.npy
# Processed disco.00078.wav in folder disco. Saved peak_spectrogram as disco.00078.wav_peak_spectrogram.npy
# Processed disco.00050.wav in folder disco. Saved peak_spectrogram as disco.00050.wav_peak_spectrogram.npy
# Processed disco.00044.wav in folder disco. Saved peak_spectrogram as disco.00044.wav_peak_spectrogram.npy
# Processed disco.00068.wav in folder disco. Saved peak_spectrogram as disco.00068.wav_peak_spectrogram.npy
# Processed disco.00040.wav in folder disco. Saved peak_spectrogram as disco.00040.wav_peak_spectrogram.npy
# Processed disco.00054.wav in folder disco. Saved peak_spectrogram as disco.00054.wav_peak_spectrogram.npy
# Processed disco.00083.wav in folder disco. Saved peak_spectrogram as disco.00083.wav_peak_spectrogram.npy
# Processed disco.00097.wav in folder disco. Saved peak_spectrogram as disco.00097.wav_peak_spectrogram.npy
# Processed disco.00096.wav in folder disco. Saved peak_spectrogram as disco.00096.wav_peak_spectrogram.npy
# Processed disco.00082.wav in folder disco. Saved peak_spectrogram as disco.00082.wav_peak_spectrogram.npy
# Processed disco.00055.wav in folder disco. Saved peak_spectrogram as disco.00055.wav_peak_spectrogram.npy
# Processed disco.00041.wav in folder disco. Saved peak_spectrogram as disco.00041.wav_peak_spectrogram.npy
# Processed disco.00069.wav in folder disco. Saved peak_spectrogram as disco.00069.wav_peak_spectrogram.npy
# Processed disco.00057.wav in folder disco. Saved peak_spectrogram as disco.00057.wav_peak_spectrogram.npy
# Processed disco.00043.wav in folder disco. Saved peak_spectrogram as disco.00043.wav_peak_spectrogram.npy
# Processed disco.00094.wav in folder disco. Saved peak_spectrogram as disco.00094.wav_peak_spectrogram.npy
# Processed disco.00080.wav in folder disco. Saved peak_spectrogram as disco.00080.wav_peak_spectrogram.npy
# Processed disco.00081.wav in folder disco. Saved peak_spectrogram as disco.00081.wav_peak_spectrogram.npy
# Processed disco.00095.wav in folder disco. Saved peak_spectrogram as disco.00095.wav_peak_spectrogram.npy
# Processed disco.00042.wav in folder disco. Saved peak_spectrogram as disco.00042.wav_peak_spectrogram.npy
# Processed disco.00056.wav in folder disco. Saved peak_spectrogram as disco.00056.wav_peak_spectrogram.npy
# Processed disco.00031.wav in folder disco. Saved peak_spectrogram as disco.00031.wav_peak_spectrogram.npy
# Processed disco.00025.wav in folder disco. Saved peak_spectrogram as disco.00025.wav_peak_spectrogram.npy
# Processed disco.00019.wav in folder disco. Saved peak_spectrogram as disco.00019.wav_peak_spectrogram.npy
# Processed disco.00018.wav in folder disco. Saved peak_spectrogram as disco.00018.wav_peak_spectrogram.npy
# Processed disco.00024.wav in folder disco. Saved peak_spectrogram as disco.00024.wav_peak_spectrogram.npy
# Processed disco.00030.wav in folder disco. Saved peak_spectrogram as disco.00030.wav_peak_spectrogram.npy
# Processed disco.00026.wav in folder disco. Saved peak_spectrogram as disco.00026.wav_peak_spectrogram.npy
# Processed disco.00032.wav in folder disco. Saved peak_spectrogram as disco.00032.wav_peak_spectrogram.npy
# Processed disco.00033.wav in folder disco. Saved peak_spectrogram as disco.00033.wav_peak_spectrogram.npy
# Processed disco.00027.wav in folder disco. Saved peak_spectrogram as disco.00027.wav_peak_spectrogram.npy
# Processed disco.00023.wav in folder disco. Saved peak_spectrogram as disco.00023.wav_peak_spectrogram.npy
# Processed disco.00037.wav in folder disco. Saved peak_spectrogram as disco.00037.wav_peak_spectrogram.npy
# Processed disco.00036.wav in folder disco. Saved peak_spectrogram as disco.00036.wav_peak_spectrogram.npy
# Processed disco.00022.wav in folder disco. Saved peak_spectrogram as disco.00022.wav_peak_spectrogram.npy
# Processed disco.00008.wav in folder disco. Saved peak_spectrogram as disco.00008.wav_peak_spectrogram.npy
# Processed disco.00034.wav in folder disco. Saved peak_spectrogram as disco.00034.wav_peak_spectrogram.npy
# Processed disco.00020.wav in folder disco. Saved peak_spectrogram as disco.00020.wav_peak_spectrogram.npy
# Processed disco.00021.wav in folder disco. Saved peak_spectrogram as disco.00021.wav_peak_spectrogram.npy
# Processed disco.00035.wav in folder disco. Saved peak_spectrogram as disco.00035.wav_peak_spectrogram.npy
# Processed disco.00009.wav in folder disco. Saved peak_spectrogram as disco.00009.wav_peak_spectrogram.npy
# Processed disco.00010.wav in folder disco. Saved peak_spectrogram as disco.00010.wav_peak_spectrogram.npy
# Processed disco.00004.wav in folder disco. Saved peak_spectrogram as disco.00004.wav_peak_spectrogram.npy
# Processed disco.00038.wav in folder disco. Saved peak_spectrogram as disco.00038.wav_peak_spectrogram.npy
# Processed disco.00039.wav in folder disco. Saved peak_spectrogram as disco.00039.wav_peak_spectrogram.npy
# Processed disco.00005.wav in folder disco. Saved peak_spectrogram as disco.00005.wav_peak_spectrogram.npy
# Processed disco.00011.wav in folder disco. Saved peak_spectrogram as disco.00011.wav_peak_spectrogram.npy
# Processed disco.00007.wav in folder disco. Saved peak_spectrogram as disco.00007.wav_peak_spectrogram.npy
# Processed disco.00013.wav in folder disco. Saved peak_spectrogram as disco.00013.wav_peak_spectrogram.npy
# Processed disco.00012.wav in folder disco. Saved peak_spectrogram as disco.00012.wav_peak_spectrogram.npy
# Processed disco.00006.wav in folder disco. Saved peak_spectrogram as disco.00006.wav_peak_spectrogram.npy
# Processed disco.00002.wav in folder disco. Saved peak_spectrogram as disco.00002.wav_peak_spectrogram.npy
# Processed disco.00016.wav in folder disco. Saved peak_spectrogram as disco.00016.wav_peak_spectrogram.npy
# Processed disco.00017.wav in folder disco. Saved peak_spectrogram as disco.00017.wav_peak_spectrogram.npy
# Processed disco.00003.wav in folder disco. Saved peak_spectrogram as disco.00003.wav_peak_spectrogram.npy
# Processed disco.00029.wav in folder disco. Saved peak_spectrogram as disco.00029.wav_peak_spectrogram.npy
# Processed disco.00015.wav in folder disco. Saved peak_spectrogram as disco.00015.wav_peak_spectrogram.npy
# Processed disco.00001.wav in folder disco. Saved peak_spectrogram as disco.00001.wav_peak_spectrogram.npy
# Processed disco.00000.wav in folder disco. Saved peak_spectrogram as disco.00000.wav_peak_spectrogram.npy
# Processed disco.00014.wav in folder disco. Saved peak_spectrogram as disco.00014.wav_peak_spectrogram.npy
# Processed disco.00028.wav in folder disco. Saved peak_spectrogram as disco.00028.wav_peak_spectrogram.npy
# Processed disco.00073.wav in folder disco. Saved peak_spectrogram as disco.00073.wav_peak_spectrogram.npy
# Processed disco.00067.wav in folder disco. Saved peak_spectrogram as disco.00067.wav_peak_spectrogram.npy
# Processed disco.00098.wav in folder disco. Saved peak_spectrogram as disco.00098.wav_peak_spectrogram.npy
# Processed disco.00099.wav in folder disco. Saved peak_spectrogram as disco.00099.wav_peak_spectrogram.npy
# Processed disco.00066.wav in folder disco. Saved peak_spectrogram as disco.00066.wav_peak_spectrogram.npy
# Processed disco.00072.wav in folder disco. Saved peak_spectrogram as disco.00072.wav_peak_spectrogram.npy
# Processed disco.00064.wav in folder disco. Saved peak_spectrogram as disco.00064.wav_peak_spectrogram.npy
# Processed disco.00070.wav in folder disco. Saved peak_spectrogram as disco.00070.wav_peak_spectrogram.npy
# Processed disco.00058.wav in folder disco. Saved peak_spectrogram as disco.00058.wav_peak_spectrogram.npy
# Processed disco.00059.wav in folder disco. Saved peak_spectrogram as disco.00059.wav_peak_spectrogram.npy
# Processed disco.00071.wav in folder disco. Saved peak_spectrogram as disco.00071.wav_peak_spectrogram.npy
# Processed disco.00065.wav in folder disco. Saved peak_spectrogram as disco.00065.wav_peak_spectrogram.npy
# Processed disco.00049.wav in folder disco. Saved peak_spectrogram as disco.00049.wav_peak_spectrogram.npy
# Processed disco.00061.wav in folder disco. Saved peak_spectrogram as disco.00061.wav_peak_spectrogram.npy
# Processed disco.00075.wav in folder disco. Saved peak_spectrogram as disco.00075.wav_peak_spectrogram.npy
# Processed disco.00074.wav in folder disco. Saved peak_spectrogram as disco.00074.wav_peak_spectrogram.npy
# Processed disco.00060.wav in folder disco. Saved peak_spectrogram as disco.00060.wav_peak_spectrogram.npy
# Processed disco.00048.wav in folder disco. Saved peak_spectrogram as disco.00048.wav_peak_spectrogram.npy
# Processed disco.00076.wav in folder disco. Saved peak_spectrogram as disco.00076.wav_peak_spectrogram.npy
# Processed disco.00062.wav in folder disco. Saved peak_spectrogram as disco.00062.wav_peak_spectrogram.npy
# Processed disco.00089.wav in folder disco. Saved peak_spectrogram as disco.00089.wav_peak_spectrogram.npy
# Processed disco.00088.wav in folder disco. Saved peak_spectrogram as disco.00088.wav_peak_spectrogram.npy
# Processed disco.00063.wav in folder disco. Saved peak_spectrogram as disco.00063.wav_peak_spectrogram.npy
# Processed disco.00077.wav in folder disco. Saved peak_spectrogram as disco.00077.wav_peak_spectrogram.npy
# unique song length in disco is [5167. 5169. 5170. 5171. 5184. 5189. 5196. 5205. 5219. 5220.]
# unique song length in npy_files is []
# Processed blues.00093.wav in folder blues. Saved peak_spectrogram as blues.00093.wav_peak_spectrogram.npy
# Processed blues.00087.wav in folder blues. Saved peak_spectrogram as blues.00087.wav_peak_spectrogram.npy
# Processed blues.00050.wav in folder blues. Saved peak_spectrogram as blues.00050.wav_peak_spectrogram.npy
# Processed blues.00044.wav in folder blues. Saved peak_spectrogram as blues.00044.wav_peak_spectrogram.npy
# Processed blues.00078.wav in folder blues. Saved peak_spectrogram as blues.00078.wav_peak_spectrogram.npy
# Processed blues.00079.wav in folder blues. Saved peak_spectrogram as blues.00079.wav_peak_spectrogram.npy
# Processed blues.00045.wav in folder blues. Saved peak_spectrogram as blues.00045.wav_peak_spectrogram.npy
# Processed blues.00051.wav in folder blues. Saved peak_spectrogram as blues.00051.wav_peak_spectrogram.npy
# Processed blues.00086.wav in folder blues. Saved peak_spectrogram as blues.00086.wav_peak_spectrogram.npy
# Processed blues.00092.wav in folder blues. Saved peak_spectrogram as blues.00092.wav_peak_spectrogram.npy
# Processed blues.00084.wav in folder blues. Saved peak_spectrogram as blues.00084.wav_peak_spectrogram.npy
# Processed blues.00090.wav in folder blues. Saved peak_spectrogram as blues.00090.wav_peak_spectrogram.npy
# Processed blues.00047.wav in folder blues. Saved peak_spectrogram as blues.00047.wav_peak_spectrogram.npy
# Processed blues.00053.wav in folder blues. Saved peak_spectrogram as blues.00053.wav_peak_spectrogram.npy
# Processed blues.00052.wav in folder blues. Saved peak_spectrogram as blues.00052.wav_peak_spectrogram.npy
# Processed blues.00046.wav in folder blues. Saved peak_spectrogram as blues.00046.wav_peak_spectrogram.npy
# Processed blues.00091.wav in folder blues. Saved peak_spectrogram as blues.00091.wav_peak_spectrogram.npy
# Processed blues.00085.wav in folder blues. Saved peak_spectrogram as blues.00085.wav_peak_spectrogram.npy
# Processed blues.00081.wav in folder blues. Saved peak_spectrogram as blues.00081.wav_peak_spectrogram.npy
# Processed blues.00095.wav in folder blues. Saved peak_spectrogram as blues.00095.wav_peak_spectrogram.npy
# Processed blues.00042.wav in folder blues. Saved peak_spectrogram as blues.00042.wav_peak_spectrogram.npy
# Processed blues.00056.wav in folder blues. Saved peak_spectrogram as blues.00056.wav_peak_spectrogram.npy
# Processed blues.00057.wav in folder blues. Saved peak_spectrogram as blues.00057.wav_peak_spectrogram.npy
# Processed blues.00043.wav in folder blues. Saved peak_spectrogram as blues.00043.wav_peak_spectrogram.npy
# Processed blues.00094.wav in folder blues. Saved peak_spectrogram as blues.00094.wav_peak_spectrogram.npy
# Processed blues.00080.wav in folder blues. Saved peak_spectrogram as blues.00080.wav_peak_spectrogram.npy
# Processed blues.00096.wav in folder blues. Saved peak_spectrogram as blues.00096.wav_peak_spectrogram.npy
# Processed blues.00082.wav in folder blues. Saved peak_spectrogram as blues.00082.wav_peak_spectrogram.npy
# Processed blues.00069.wav in folder blues. Saved peak_spectrogram as blues.00069.wav_peak_spectrogram.npy
# Processed blues.00055.wav in folder blues. Saved peak_spectrogram as blues.00055.wav_peak_spectrogram.npy
# Processed blues.00041.wav in folder blues. Saved peak_spectrogram as blues.00041.wav_peak_spectrogram.npy
# Processed blues.00040.wav in folder blues. Saved peak_spectrogram as blues.00040.wav_peak_spectrogram.npy
# Processed blues.00054.wav in folder blues. Saved peak_spectrogram as blues.00054.wav_peak_spectrogram.npy
# Processed blues.00068.wav in folder blues. Saved peak_spectrogram as blues.00068.wav_peak_spectrogram.npy
# Processed blues.00083.wav in folder blues. Saved peak_spectrogram as blues.00083.wav_peak_spectrogram.npy
# Processed blues.00097.wav in folder blues. Saved peak_spectrogram as blues.00097.wav_peak_spectrogram.npy
# Processed blues.00033.wav in folder blues. Saved peak_spectrogram as blues.00033.wav_peak_spectrogram.npy
# Processed blues.00027.wav in folder blues. Saved peak_spectrogram as blues.00027.wav_peak_spectrogram.npy
# Processed blues.00026.wav in folder blues. Saved peak_spectrogram as blues.00026.wav_peak_spectrogram.npy
# Processed blues.00032.wav in folder blues. Saved peak_spectrogram as blues.00032.wav_peak_spectrogram.npy
# Processed blues.00024.wav in folder blues. Saved peak_spectrogram as blues.00024.wav_peak_spectrogram.npy
# Processed blues.00030.wav in folder blues. Saved peak_spectrogram as blues.00030.wav_peak_spectrogram.npy
# Processed blues.00018.wav in folder blues. Saved peak_spectrogram as blues.00018.wav_peak_spectrogram.npy
# Processed blues.00019.wav in folder blues. Saved peak_spectrogram as blues.00019.wav_peak_spectrogram.npy
# Processed blues.00031.wav in folder blues. Saved peak_spectrogram as blues.00031.wav_peak_spectrogram.npy
# Processed blues.00025.wav in folder blues. Saved peak_spectrogram as blues.00025.wav_peak_spectrogram.npy
# Processed blues.00009.wav in folder blues. Saved peak_spectrogram as blues.00009.wav_peak_spectrogram.npy
# Processed blues.00021.wav in folder blues. Saved peak_spectrogram as blues.00021.wav_peak_spectrogram.npy
# Processed blues.00035.wav in folder blues. Saved peak_spectrogram as blues.00035.wav_peak_spectrogram.npy
# Processed blues.00034.wav in folder blues. Saved peak_spectrogram as blues.00034.wav_peak_spectrogram.npy
# Processed blues.00020.wav in folder blues. Saved peak_spectrogram as blues.00020.wav_peak_spectrogram.npy
# Processed blues.00008.wav in folder blues. Saved peak_spectrogram as blues.00008.wav_peak_spectrogram.npy
# Processed blues.00036.wav in folder blues. Saved peak_spectrogram as blues.00036.wav_peak_spectrogram.npy
# Processed blues.00022.wav in folder blues. Saved peak_spectrogram as blues.00022.wav_peak_spectrogram.npy
# Processed blues.00023.wav in folder blues. Saved peak_spectrogram as blues.00023.wav_peak_spectrogram.npy
# Processed blues.00037.wav in folder blues. Saved peak_spectrogram as blues.00037.wav_peak_spectrogram.npy
# Processed blues.00012.wav in folder blues. Saved peak_spectrogram as blues.00012.wav_peak_spectrogram.npy
# Processed blues.00006.wav in folder blues. Saved peak_spectrogram as blues.00006.wav_peak_spectrogram.npy
# Processed blues.00007.wav in folder blues. Saved peak_spectrogram as blues.00007.wav_peak_spectrogram.npy
# Processed blues.00013.wav in folder blues. Saved peak_spectrogram as blues.00013.wav_peak_spectrogram.npy
# Processed blues.00005.wav in folder blues. Saved peak_spectrogram as blues.00005.wav_peak_spectrogram.npy
# Processed blues.00011.wav in folder blues. Saved peak_spectrogram as blues.00011.wav_peak_spectrogram.npy
# Processed blues.00039.wav in folder blues. Saved peak_spectrogram as blues.00039.wav_peak_spectrogram.npy
# Processed blues.00038.wav in folder blues. Saved peak_spectrogram as blues.00038.wav_peak_spectrogram.npy
# Processed blues.00010.wav in folder blues. Saved peak_spectrogram as blues.00010.wav_peak_spectrogram.npy
# Processed blues.00004.wav in folder blues. Saved peak_spectrogram as blues.00004.wav_peak_spectrogram.npy
# Processed blues.00028.wav in folder blues. Saved peak_spectrogram as blues.00028.wav_peak_spectrogram.npy
# Processed blues.00000.wav in folder blues. Saved peak_spectrogram as blues.00000.wav_peak_spectrogram.npy
# Processed blues.00014.wav in folder blues. Saved peak_spectrogram as blues.00014.wav_peak_spectrogram.npy
# Processed blues.00015.wav in folder blues. Saved peak_spectrogram as blues.00015.wav_peak_spectrogram.npy
# Processed blues.00001.wav in folder blues. Saved peak_spectrogram as blues.00001.wav_peak_spectrogram.npy
# Processed blues.00029.wav in folder blues. Saved peak_spectrogram as blues.00029.wav_peak_spectrogram.npy
# Processed blues.00017.wav in folder blues. Saved peak_spectrogram as blues.00017.wav_peak_spectrogram.npy
# Processed blues.00003.wav in folder blues. Saved peak_spectrogram as blues.00003.wav_peak_spectrogram.npy
# Processed blues.00002.wav in folder blues. Saved peak_spectrogram as blues.00002.wav_peak_spectrogram.npy
# Processed blues.00016.wav in folder blues. Saved peak_spectrogram as blues.00016.wav_peak_spectrogram.npy
# Processed blues.00071.wav in folder blues. Saved peak_spectrogram as blues.00071.wav_peak_spectrogram.npy
# Processed blues.00065.wav in folder blues. Saved peak_spectrogram as blues.00065.wav_peak_spectrogram.npy
# Processed blues.00059.wav in folder blues. Saved peak_spectrogram as blues.00059.wav_peak_spectrogram.npy
# Processed blues.00058.wav in folder blues. Saved peak_spectrogram as blues.00058.wav_peak_spectrogram.npy
# Processed blues.00064.wav in folder blues. Saved peak_spectrogram as blues.00064.wav_peak_spectrogram.npy
# Processed blues.00070.wav in folder blues. Saved peak_spectrogram as blues.00070.wav_peak_spectrogram.npy
# Processed blues.00099.wav in folder blues. Saved peak_spectrogram as blues.00099.wav_peak_spectrogram.npy
# Processed blues.00066.wav in folder blues. Saved peak_spectrogram as blues.00066.wav_peak_spectrogram.npy
# Processed blues.00072.wav in folder blues. Saved peak_spectrogram as blues.00072.wav_peak_spectrogram.npy
# Processed blues.00073.wav in folder blues. Saved peak_spectrogram as blues.00073.wav_peak_spectrogram.npy
# Processed blues.00067.wav in folder blues. Saved peak_spectrogram as blues.00067.wav_peak_spectrogram.npy
# Processed blues.00098.wav in folder blues. Saved peak_spectrogram as blues.00098.wav_peak_spectrogram.npy
# Processed blues.00088.wav in folder blues. Saved peak_spectrogram as blues.00088.wav_peak_spectrogram.npy
# Processed blues.00063.wav in folder blues. Saved peak_spectrogram as blues.00063.wav_peak_spectrogram.npy
# Processed blues.00077.wav in folder blues. Saved peak_spectrogram as blues.00077.wav_peak_spectrogram.npy
# Processed blues.00076.wav in folder blues. Saved peak_spectrogram as blues.00076.wav_peak_spectrogram.npy
# Processed blues.00062.wav in folder blues. Saved peak_spectrogram as blues.00062.wav_peak_spectrogram.npy
# Processed blues.00089.wav in folder blues. Saved peak_spectrogram as blues.00089.wav_peak_spectrogram.npy
# Processed blues.00048.wav in folder blues. Saved peak_spectrogram as blues.00048.wav_peak_spectrogram.npy
# Processed blues.00074.wav in folder blues. Saved peak_spectrogram as blues.00074.wav_peak_spectrogram.npy
# Processed blues.00060.wav in folder blues. Saved peak_spectrogram as blues.00060.wav_peak_spectrogram.npy
# Processed blues.00061.wav in folder blues. Saved peak_spectrogram as blues.00061.wav_peak_spectrogram.npy
# Processed blues.00075.wav in folder blues. Saved peak_spectrogram as blues.00075.wav_peak_spectrogram.npy
# Processed blues.00049.wav in folder blues. Saved peak_spectrogram as blues.00049.wav_peak_spectrogram.npy
# unique song length in blues is [5171.]
# Processed reggae.00080.wav in folder reggae. Saved peak_spectrogram as reggae.00080.wav_peak_spectrogram.npy
# Processed reggae.00094.wav in folder reggae. Saved peak_spectrogram as reggae.00094.wav_peak_spectrogram.npy
# Processed reggae.00043.wav in folder reggae. Saved peak_spectrogram as reggae.00043.wav_peak_spectrogram.npy
# Processed reggae.00057.wav in folder reggae. Saved peak_spectrogram as reggae.00057.wav_peak_spectrogram.npy
# Processed reggae.00056.wav in folder reggae. Saved peak_spectrogram as reggae.00056.wav_peak_spectrogram.npy
# Processed reggae.00042.wav in folder reggae. Saved peak_spectrogram as reggae.00042.wav_peak_spectrogram.npy
# Processed reggae.00095.wav in folder reggae. Saved peak_spectrogram as reggae.00095.wav_peak_spectrogram.npy
# Processed reggae.00081.wav in folder reggae. Saved peak_spectrogram as reggae.00081.wav_peak_spectrogram.npy
# Processed reggae.00097.wav in folder reggae. Saved peak_spectrogram as reggae.00097.wav_peak_spectrogram.npy
# Processed reggae.00083.wav in folder reggae. Saved peak_spectrogram as reggae.00083.wav_peak_spectrogram.npy
# Processed reggae.00054.wav in folder reggae. Saved peak_spectrogram as reggae.00054.wav_peak_spectrogram.npy
# Processed reggae.00040.wav in folder reggae. Saved peak_spectrogram as reggae.00040.wav_peak_spectrogram.npy
# Processed reggae.00068.wav in folder reggae. Saved peak_spectrogram as reggae.00068.wav_peak_spectrogram.npy
# Processed reggae.00069.wav in folder reggae. Saved peak_spectrogram as reggae.00069.wav_peak_spectrogram.npy
# Processed reggae.00041.wav in folder reggae. Saved peak_spectrogram as reggae.00041.wav_peak_spectrogram.npy
# Processed reggae.00055.wav in folder reggae. Saved peak_spectrogram as reggae.00055.wav_peak_spectrogram.npy
# Processed reggae.00082.wav in folder reggae. Saved peak_spectrogram as reggae.00082.wav_peak_spectrogram.npy
# Processed reggae.00096.wav in folder reggae. Saved peak_spectrogram as reggae.00096.wav_peak_spectrogram.npy
# Processed reggae.00092.wav in folder reggae. Saved peak_spectrogram as reggae.00092.wav_peak_spectrogram.npy
# Processed reggae.00086.wav in folder reggae. Saved peak_spectrogram as reggae.00086.wav_peak_spectrogram.npy
# Processed reggae.00079.wav in folder reggae. Saved peak_spectrogram as reggae.00079.wav_peak_spectrogram.npy
# Processed reggae.00051.wav in folder reggae. Saved peak_spectrogram as reggae.00051.wav_peak_spectrogram.npy
# Processed reggae.00045.wav in folder reggae. Saved peak_spectrogram as reggae.00045.wav_peak_spectrogram.npy
# Processed reggae.00044.wav in folder reggae. Saved peak_spectrogram as reggae.00044.wav_peak_spectrogram.npy
# Processed reggae.00050.wav in folder reggae. Saved peak_spectrogram as reggae.00050.wav_peak_spectrogram.npy
# Processed reggae.00078.wav in folder reggae. Saved peak_spectrogram as reggae.00078.wav_peak_spectrogram.npy
# Processed reggae.00087.wav in folder reggae. Saved peak_spectrogram as reggae.00087.wav_peak_spectrogram.npy
# Processed reggae.00093.wav in folder reggae. Saved peak_spectrogram as reggae.00093.wav_peak_spectrogram.npy
# Processed reggae.00085.wav in folder reggae. Saved peak_spectrogram as reggae.00085.wav_peak_spectrogram.npy
# Processed reggae.00091.wav in folder reggae. Saved peak_spectrogram as reggae.00091.wav_peak_spectrogram.npy
# Processed reggae.00046.wav in folder reggae. Saved peak_spectrogram as reggae.00046.wav_peak_spectrogram.npy
# Processed reggae.00052.wav in folder reggae. Saved peak_spectrogram as reggae.00052.wav_peak_spectrogram.npy
# Processed reggae.00053.wav in folder reggae. Saved peak_spectrogram as reggae.00053.wav_peak_spectrogram.npy
# Processed reggae.00047.wav in folder reggae. Saved peak_spectrogram as reggae.00047.wav_peak_spectrogram.npy
# Processed reggae.00090.wav in folder reggae. Saved peak_spectrogram as reggae.00090.wav_peak_spectrogram.npy
# Processed reggae.00084.wav in folder reggae. Saved peak_spectrogram as reggae.00084.wav_peak_spectrogram.npy
# Processed reggae.00020.wav in folder reggae. Saved peak_spectrogram as reggae.00020.wav_peak_spectrogram.npy
# Processed reggae.00034.wav in folder reggae. Saved peak_spectrogram as reggae.00034.wav_peak_spectrogram.npy
# Processed reggae.00008.wav in folder reggae. Saved peak_spectrogram as reggae.00008.wav_peak_spectrogram.npy
# Processed reggae.00009.wav in folder reggae. Saved peak_spectrogram as reggae.00009.wav_peak_spectrogram.npy
# Processed reggae.00035.wav in folder reggae. Saved peak_spectrogram as reggae.00035.wav_peak_spectrogram.npy
# Processed reggae.00021.wav in folder reggae. Saved peak_spectrogram as reggae.00021.wav_peak_spectrogram.npy
# Processed reggae.00037.wav in folder reggae. Saved peak_spectrogram as reggae.00037.wav_peak_spectrogram.npy
# Processed reggae.00023.wav in folder reggae. Saved peak_spectrogram as reggae.00023.wav_peak_spectrogram.npy
# Processed reggae.00022.wav in folder reggae. Saved peak_spectrogram as reggae.00022.wav_peak_spectrogram.npy
# Processed reggae.00036.wav in folder reggae. Saved peak_spectrogram as reggae.00036.wav_peak_spectrogram.npy
# Processed reggae.00032.wav in folder reggae. Saved peak_spectrogram as reggae.00032.wav_peak_spectrogram.npy
# Processed reggae.00026.wav in folder reggae. Saved peak_spectrogram as reggae.00026.wav_peak_spectrogram.npy
# Processed reggae.00027.wav in folder reggae. Saved peak_spectrogram as reggae.00027.wav_peak_spectrogram.npy
# Processed reggae.00033.wav in folder reggae. Saved peak_spectrogram as reggae.00033.wav_peak_spectrogram.npy
# Processed reggae.00019.wav in folder reggae. Saved peak_spectrogram as reggae.00019.wav_peak_spectrogram.npy
# Processed reggae.00025.wav in folder reggae. Saved peak_spectrogram as reggae.00025.wav_peak_spectrogram.npy
# Processed reggae.00031.wav in folder reggae. Saved peak_spectrogram as reggae.00031.wav_peak_spectrogram.npy
# Processed reggae.00030.wav in folder reggae. Saved peak_spectrogram as reggae.00030.wav_peak_spectrogram.npy
# ...
# Processed country.00037.wav in folder country. Saved peak_spectrogram as country.00037.wav_peak_spectrogram.npy
# Processed country.00033.wav in folder country. Saved peak_spectrogram as country.00033.wav_peak_spectrogram.npy
# Processed country.00027.wav in folder country. Saved peak_spectrogram as country.00027.wav_peak_spectrogram.npy
# Processed country.00026.wav in folder country. Saved peak_spectrogram as country.00026.wav_peak_spectrogram.npy
# Processed country.00032.wav in folder country. Saved peak_spectrogram as country.00032.wav_peak_spectrogram.npy
# Processed country.00024.wav in folder country. Saved peak_spectrogram as country.00024.wav_peak_spectrogram.npy
# Processed country.00030.wav in folder country. Saved peak_spectrogram as country.00030.wav_peak_spectrogram.npy
# Processed country.00018.wav in folder country. Saved peak_spectrogram as country.00018.wav_peak_spectrogram.npy
# Processed country.00019.wav in folder country. Saved peak_spectrogram as country.00019.wav_peak_spectrogram.npy
# Processed country.00031.wav in folder country. Saved peak_spectrogram as country.00031.wav_peak_spectrogram.npy
# Processed country.00025.wav in folder country. Saved peak_spectrogram as country.00025.wav_peak_spectrogram.npy
# Processed country.00081.wav in folder country. Saved peak_spectrogram as country.00081.wav_peak_spectrogram.npy
# Processed country.00095.wav in folder country. Saved peak_spectrogram as country.00095.wav_peak_spectrogram.npy
# Processed country.00042.wav in folder country. Saved peak_spectrogram as country.00042.wav_peak_spectrogram.npy
# Processed country.00056.wav in folder country. Saved peak_spectrogram as country.00056.wav_peak_spectrogram.npy
# Processed country.00057.wav in folder country. Saved peak_spectrogram as country.00057.wav_peak_spectrogram.npy
# Processed country.00043.wav in folder country. Saved peak_spectrogram as country.00043.wav_peak_spectrogram.npy
# Processed country.00094.wav in folder country. Saved peak_spectrogram as country.00094.wav_peak_spectrogram.npy
# Processed country.00080.wav in folder country. Saved peak_spectrogram as country.00080.wav_peak_spectrogram.npy
# Processed country.00096.wav in folder country. Saved peak_spectrogram as country.00096.wav_peak_spectrogram.npy
# Processed country.00082.wav in folder country. Saved peak_spectrogram as country.00082.wav_peak_spectrogram.npy
# Processed country.00069.wav in folder country. Saved peak_spectrogram as country.00069.wav_peak_spectrogram.npy
# Processed country.00055.wav in folder country. Saved peak_spectrogram as country.00055.wav_peak_spectrogram.npy
# Processed country.00041.wav in folder country. Saved peak_spectrogram as country.00041.wav_peak_spectrogram.npy
# Processed country.00040.wav in folder country. Saved peak_spectrogram as country.00040.wav_peak_spectrogram.npy
# Processed country.00054.wav in folder country. Saved peak_spectrogram as country.00054.wav_peak_spectrogram.npy
# Processed country.00068.wav in folder country. Saved peak_spectrogram as country.00068.wav_peak_spectrogram.npy
# Processed country.00083.wav in folder country. Saved peak_spectrogram as country.00083.wav_peak_spectrogram.npy
# Processed country.00097.wav in folder country. Saved peak_spectrogram as country.00097.wav_peak_spectrogram.npy
# Processed country.00093.wav in folder country. Saved peak_spectrogram as country.00093.wav_peak_spectrogram.npy
# Processed country.00087.wav in folder country. Saved peak_spectrogram as country.00087.wav_peak_spectrogram.npy
# Processed country.00050.wav in folder country. Saved peak_spectrogram as country.00050.wav_peak_spectrogram.npy
# Processed country.00044.wav in folder country. Saved peak_spectrogram as country.00044.wav_peak_spectrogram.npy
# Processed country.00078.wav in folder country. Saved peak_spectrogram as country.00078.wav_peak_spectrogram.npy
# Processed country.00079.wav in folder country. Saved peak_spectrogram as country.00079.wav_peak_spectrogram.npy
# Processed country.00045.wav in folder country. Saved peak_spectrogram as country.00045.wav_peak_spectrogram.npy
# Processed country.00051.wav in folder country. Saved peak_spectrogram as country.00051.wav_peak_spectrogram.npy
# Processed country.00086.wav in folder country. Saved peak_spectrogram as country.00086.wav_peak_spectrogram.npy
# Processed country.00092.wav in folder country. Saved peak_spectrogram as country.00092.wav_peak_spectrogram.npy
# Processed country.00084.wav in folder country. Saved peak_spectrogram as country.00084.wav_peak_spectrogram.npy
# Processed country.00090.wav in folder country. Saved peak_spectrogram as country.00090.wav_peak_spectrogram.npy
# Processed country.00047.wav in folder country. Saved peak_spectrogram as country.00047.wav_peak_spectrogram.npy
# Processed country.00053.wav in folder country. Saved peak_spectrogram as country.00053.wav_peak_spectrogram.npy
# Processed country.00052.wav in folder country. Saved peak_spectrogram as country.00052.wav_peak_spectrogram.npy
# Processed country.00046.wav in folder country. Saved peak_spectrogram as country.00046.wav_peak_spectrogram.npy
# Processed country.00091.wav in folder country. Saved peak_spectrogram as country.00091.wav_peak_spectrogram.npy
# Processed country.00085.wav in folder country. Saved peak_spectrogram as country.00085.wav_peak_spectrogram.npy
# unique song length in country is [5165. 5168. 5171. 5183. 5186. 5210. 5226. 5232.]
# Processed jazz.00016.wav in folder jazz. Saved peak_spectrogram as jazz.00016.wav_peak_spectrogram.npy
# Processed jazz.00002.wav in folder jazz. Saved peak_spectrogram as jazz.00002.wav_peak_spectrogram.npy
# Processed jazz.00003.wav in folder jazz. Saved peak_spectrogram as jazz.00003.wav_peak_spectrogram.npy
# Processed jazz.00017.wav in folder jazz. Saved peak_spectrogram as jazz.00017.wav_peak_spectrogram.npy
# Processed jazz.00001.wav in folder jazz. Saved peak_spectrogram as jazz.00001.wav_peak_spectrogram.npy
# Processed jazz.00015.wav in folder jazz. Saved peak_spectrogram as jazz.00015.wav_peak_spectrogram.npy
# Processed jazz.00029.wav in folder jazz. Saved peak_spectrogram as jazz.00029.wav_peak_spectrogram.npy
# Processed jazz.00028.wav in folder jazz. Saved peak_spectrogram as jazz.00028.wav_peak_spectrogram.npy
# Processed jazz.00014.wav in folder jazz. Saved peak_spectrogram as jazz.00014.wav_peak_spectrogram.npy
# Processed jazz.00000.wav in folder jazz. Saved peak_spectrogram as jazz.00000.wav_peak_spectrogram.npy
# Processed jazz.00038.wav in folder jazz. Saved peak_spectrogram as jazz.00038.wav_peak_spectrogram.npy
# Processed jazz.00004.wav in folder jazz. Saved peak_spectrogram as jazz.00004.wav_peak_spectrogram.npy
# Processed jazz.00010.wav in folder jazz. Saved peak_spectrogram as jazz.00010.wav_peak_spectrogram.npy
# Processed jazz.00011.wav in folder jazz. Saved peak_spectrogram as jazz.00011.wav_peak_spectrogram.npy
# Processed jazz.00005.wav in folder jazz. Saved peak_spectrogram as jazz.00005.wav_peak_spectrogram.npy
# Processed jazz.00039.wav in folder jazz. Saved peak_spectrogram as jazz.00039.wav_peak_spectrogram.npy
# Processed jazz.00013.wav in folder jazz. Saved peak_spectrogram as jazz.00013.wav_peak_spectrogram.npy
# Processed jazz.00007.wav in folder jazz. Saved peak_spectrogram as jazz.00007.wav_peak_spectrogram.npy
# Processed jazz.00006.wav in folder jazz. Saved peak_spectrogram as jazz.00006.wav_peak_spectrogram.npy
# Processed jazz.00012.wav in folder jazz. Saved peak_spectrogram as jazz.00012.wav_peak_spectrogram.npy
# Processed jazz.00075.wav in folder jazz. Saved peak_spectrogram as jazz.00075.wav_peak_spectrogram.npy
# Processed jazz.00061.wav in folder jazz. Saved peak_spectrogram as jazz.00061.wav_peak_spectrogram.npy
# Processed jazz.00049.wav in folder jazz. Saved peak_spectrogram as jazz.00049.wav_peak_spectrogram.npy
# Processed jazz.00048.wav in folder jazz. Saved peak_spectrogram as jazz.00048.wav_peak_spectrogram.npy
# Processed jazz.00060.wav in folder jazz. Saved peak_spectrogram as jazz.00060.wav_peak_spectrogram.npy
# Processed jazz.00074.wav in folder jazz. Saved peak_spectrogram as jazz.00074.wav_peak_spectrogram.npy
# Processed jazz.00062.wav in folder jazz. Saved peak_spectrogram as jazz.00062.wav_peak_spectrogram.npy
# Processed jazz.00076.wav in folder jazz. Saved peak_spectrogram as jazz.00076.wav_peak_spectrogram.npy
# Processed jazz.00089.wav in folder jazz. Saved peak_spectrogram as jazz.00089.wav_peak_spectrogram.npy
# Processed jazz.00088.wav in folder jazz. Saved peak_spectrogram as jazz.00088.wav_peak_spectrogram.npy
# Processed jazz.00077.wav in folder jazz. Saved peak_spectrogram as jazz.00077.wav_peak_spectrogram.npy
# Processed jazz.00063.wav in folder jazz. Saved peak_spectrogram as jazz.00063.wav_peak_spectrogram.npy
# Processed jazz.00067.wav in folder jazz. Saved peak_spectrogram as jazz.00067.wav_peak_spectrogram.npy
# Processed jazz.00073.wav in folder jazz. Saved peak_spectrogram as jazz.00073.wav_peak_spectrogram.npy
# Processed jazz.00098.wav in folder jazz. Saved peak_spectrogram as jazz.00098.wav_peak_spectrogram.npy
# Processed jazz.00099.wav in folder jazz. Saved peak_spectrogram as jazz.00099.wav_peak_spectrogram.npy
# Processed jazz.00072.wav in folder jazz. Saved peak_spectrogram as jazz.00072.wav_peak_spectrogram.npy
# Processed jazz.00066.wav in folder jazz. Saved peak_spectrogram as jazz.00066.wav_peak_spectrogram.npy
# Processed jazz.00058.wav in folder jazz. Saved peak_spectrogram as jazz.00058.wav_peak_spectrogram.npy
# Processed jazz.00070.wav in folder jazz. Saved peak_spectrogram as jazz.00070.wav_peak_spectrogram.npy
# Processed jazz.00064.wav in folder jazz. Saved peak_spectrogram as jazz.00064.wav_peak_spectrogram.npy
# Processed jazz.00065.wav in folder jazz. Saved peak_spectrogram as jazz.00065.wav_peak_spectrogram.npy
# Processed jazz.00071.wav in folder jazz. Saved peak_spectrogram as jazz.00071.wav_peak_spectrogram.npy
# Processed jazz.00059.wav in folder jazz. Saved peak_spectrogram as jazz.00059.wav_peak_spectrogram.npy
# /Users/quinn/Documents/local_framework/framework/pyframework/lib/python3.10/site-packages/librosa/util/decorators.py:88: UserWarning: PySoundFile failed. Trying audioread instead.
#   return f(*args, **kwargs)
# Error processing jazz.00054.wav in folder jazz:
# Processed jazz.00040.wav in folder jazz. Saved peak_spectrogram as jazz.00040.wav_peak_spectrogram.npy
# Processed jazz.00068.wav in folder jazz. Saved peak_spectrogram as jazz.00068.wav_peak_spectrogram.npy
# Processed jazz.00097.wav in folder jazz. Saved peak_spectrogram as jazz.00097.wav_peak_spectrogram.npy
# Processed jazz.00083.wav in folder jazz. Saved peak_spectrogram as jazz.00083.wav_peak_spectrogram.npy
# Processed jazz.00082.wav in folder jazz. Saved peak_spectrogram as jazz.00082.wav_peak_spectrogram.npy
# Processed jazz.00096.wav in folder jazz. Saved peak_spectrogram as jazz.00096.wav_peak_spectrogram.npy
# Processed jazz.00069.wav in folder jazz. Saved peak_spectrogram as jazz.00069.wav_peak_spectrogram.npy
# Processed jazz.00041.wav in folder jazz. Saved peak_spectrogram as jazz.00041.wav_peak_spectrogram.npy
# Processed jazz.00055.wav in folder jazz. Saved peak_spectrogram as jazz.00055.wav_peak_spectrogram.npy
# Processed jazz.00043.wav in folder jazz. Saved peak_spectrogram as jazz.00043.wav_peak_spectrogram.npy
# Processed jazz.00057.wav in folder jazz. Saved peak_spectrogram as jazz.00057.wav_peak_spectrogram.npy
# Processed jazz.00080.wav in folder jazz. Saved peak_spectrogram as jazz.00080.wav_peak_spectrogram.npy
# Processed jazz.00094.wav in folder jazz. Saved peak_spectrogram as jazz.00094.wav_peak_spectrogram.npy
# Processed jazz.00095.wav in folder jazz. Saved peak_spectrogram as jazz.00095.wav_peak_spectrogram.npy
# Processed jazz.00081.wav in folder jazz. Saved peak_spectrogram as jazz.00081.wav_peak_spectrogram.npy
# Processed jazz.00056.wav in folder jazz. Saved peak_spectrogram as jazz.00056.wav_peak_spectrogram.npy
# Processed jazz.00042.wav in folder jazz. Saved peak_spectrogram as jazz.00042.wav_peak_spectrogram.npy
# Processed jazz.00046.wav in folder jazz. Saved peak_spectrogram as jazz.00046.wav_peak_spectrogram.npy
# Processed jazz.00052.wav in folder jazz. Saved peak_spectrogram as jazz.00052.wav_peak_spectrogram.npy
# Processed jazz.00085.wav in folder jazz. Saved peak_spectrogram as jazz.00085.wav_peak_spectrogram.npy
# Processed jazz.00091.wav in folder jazz. Saved peak_spectrogram as jazz.00091.wav_peak_spectrogram.npy
# Processed jazz.00090.wav in folder jazz. Saved peak_spectrogram as jazz.00090.wav_peak_spectrogram.npy
# Processed jazz.00084.wav in folder jazz. Saved peak_spectrogram as jazz.00084.wav_peak_spectrogram.npy
# Processed jazz.00053.wav in folder jazz. Saved peak_spectrogram as jazz.00053.wav_peak_spectrogram.npy
# Processed jazz.00047.wav in folder jazz. Saved peak_spectrogram as jazz.00047.wav_peak_spectrogram.npy
# Processed jazz.00079.wav in folder jazz. Saved peak_spectrogram as jazz.00079.wav_peak_spectrogram.npy
# Processed jazz.00051.wav in folder jazz. Saved peak_spectrogram as jazz.00051.wav_peak_spectrogram.npy
# Processed jazz.00045.wav in folder jazz. Saved peak_spectrogram as jazz.00045.wav_peak_spectrogram.npy
# Processed jazz.00092.wav in folder jazz. Saved peak_spectrogram as jazz.00092.wav_peak_spectrogram.npy
# Processed jazz.00086.wav in folder jazz. Saved peak_spectrogram as jazz.00086.wav_peak_spectrogram.npy
# Processed jazz.00087.wav in folder jazz. Saved peak_spectrogram as jazz.00087.wav_peak_spectrogram.npy
# Processed jazz.00093.wav in folder jazz. Saved peak_spectrogram as jazz.00093.wav_peak_spectrogram.npy
# Processed jazz.00044.wav in folder jazz. Saved peak_spectrogram as jazz.00044.wav_peak_spectrogram.npy
# Processed jazz.00050.wav in folder jazz. Saved peak_spectrogram as jazz.00050.wav_peak_spectrogram.npy
# Processed jazz.00078.wav in folder jazz. Saved peak_spectrogram as jazz.00078.wav_peak_spectrogram.npy
# Processed jazz.00037.wav in folder jazz. Saved peak_spectrogram as jazz.00037.wav_peak_spectrogram.npy
# Processed jazz.00023.wav in folder jazz. Saved peak_spectrogram as jazz.00023.wav_peak_spectrogram.npy
# Processed jazz.00022.wav in folder jazz. Saved peak_spectrogram as jazz.00022.wav_peak_spectrogram.npy
# Processed jazz.00036.wav in folder jazz. Saved peak_spectrogram as jazz.00036.wav_peak_spectrogram.npy
# Processed jazz.00020.wav in folder jazz. Saved peak_spectrogram as jazz.00020.wav_peak_spectrogram.npy
# Processed jazz.00034.wav in folder jazz. Saved peak_spectrogram as jazz.00034.wav_peak_spectrogram.npy
# Processed jazz.00008.wav in folder jazz. Saved peak_spectrogram as jazz.00008.wav_peak_spectrogram.npy
# Processed jazz.00009.wav in folder jazz. Saved peak_spectrogram as jazz.00009.wav_peak_spectrogram.npy
# Processed jazz.00035.wav in folder jazz. Saved peak_spectrogram as jazz.00035.wav_peak_spectrogram.npy
# Processed jazz.00021.wav in folder jazz. Saved peak_spectrogram as jazz.00021.wav_peak_spectrogram.npy
# Processed jazz.00019.wav in folder jazz. Saved peak_spectrogram as jazz.00019.wav_peak_spectrogram.npy
# Processed jazz.00025.wav in folder jazz. Saved peak_spectrogram as jazz.00025.wav_peak_spectrogram.npy
# Processed jazz.00031.wav in folder jazz. Saved peak_spectrogram as jazz.00031.wav_peak_spectrogram.npy
# Processed jazz.00030.wav in folder jazz. Saved peak_spectrogram as jazz.00030.wav_peak_spectrogram.npy
# Processed jazz.00024.wav in folder jazz. Saved peak_spectrogram as jazz.00024.wav_peak_spectrogram.npy
# Processed jazz.00018.wav in folder jazz. Saved peak_spectrogram as jazz.00018.wav_peak_spectrogram.npy
# Processed jazz.00032.wav in folder jazz. Saved peak_spectrogram as jazz.00032.wav_peak_spectrogram.npy
# Processed jazz.00026.wav in folder jazz. Saved peak_spectrogram as jazz.00026.wav_peak_spectrogram.npy
# Processed jazz.00027.wav in folder jazz. Saved peak_spectrogram as jazz.00027.wav_peak_spectrogram.npy
# Processed jazz.00033.wav in folder jazz. Saved peak_spectrogram as jazz.00033.wav_peak_spectrogram.npy
# unique song length in jazz is [5170. 5171. 5172. 5198. 5203. 5210. 5215. 5229. 5251.]
# unique sample rates for all genres [22050.]
# minimum song length is 5157

# %%
'''
def load_npy_files_with_prefix(directory, prefix, min_song_len):
    npy_files = [file for file in os.listdir(directory) if file.startswith(prefix) and file.endswith('.npy')]
    npy_files.sort()  # Sort the files for consistent order

    if len(npy_files) == 0:
        raise ValueError(f"No npy files found with prefix '{prefix}' in directory '{directory}'")
    loaded_data = []

    
    for npy_file in npy_files:
        npy_path = os.path.join(directory, npy_file)
        data = np.load(npy_path)

        #trim the data array to the desired shape (min_song_len)
        if len(data[1]) > min_song_len:
            trimmed_data = data[:, :min_song_len]
            loaded_data.append(trimmed_data)
        else:
            loaded_data.append(data)
            
    return np.array(loaded_data)
'''
# Out:
# '\ndef load_npy_files_with_prefix(directory, prefix, min_song_len):\n    npy_files = [file for file in os.listdir(directory) if file.startswith(prefix) and file.endswith(\'.npy\')]\n    npy_files.sort()  # Sort the files for consistent order\n\n    if len(npy_files) == 0:\n        raise ValueError(f"No npy files found with prefix \'{prefix}\' in directory \'{directory}\'")\n    loaded_data = []\n\n    \n    for npy_file in npy_files:\n        npy_path = os.path.join(directory, npy_file)\n        data = np.load(npy_path)\n\n        #trim the data array to the desired shape (min_song_len)\n        if len(data[1]) > min_song_len:\n            trimmed_data = data[:, :min_song_len]\n            loaded_data.append(trimmed_data)\n        else:\n            loaded_data.append(data)\n            \n    return np.array(loaded_data)\n'

# %%
'''
directory = new_folder_path

# Loading hiphop songs
X_hiphop = load_npy_files_with_prefix(directory = directory, prefix = 'hiphop', min_song_len=min_song_len)
y_hiphop = ['hiphop'] * len(X_hiphop)

# Loading country songs
X_country = load_npy_files_with_prefix(directory = directory, prefix = 'country', min_song_len=min_song_len)
y_country = ['country'] * len(X_country)

# Combining the data and labels
X = np.concatenate((X_hiphop, X_country), axis=0)
y = np.concatenate((y_hiphop, y_country), axis=0)

X = (np.rint(X)).astype(int)
'''
# Out:
# "\ndirectory = new_folder_path\n\n# Loading hiphop songs\nX_hiphop = load_npy_files_with_prefix(directory = directory, prefix = 'hiphop', min_song_len=min_song_len)\ny_hiphop = ['hiphop'] * len(X_hiphop)\n\n# Loading country songs\nX_country = load_npy_files_with_prefix(directory = directory, prefix = 'country', min_song_len=min_song_len)\ny_country = ['country'] * len(X_country)\n\n# Combining the data and labels\nX = np.concatenate((X_hiphop, X_country), axis=0)\ny = np.concatenate((y_hiphop, y_country), axis=0)\n\nX = (np.rint(X)).astype(int)\n"

# %%
def load_npy_files(directory, min_song_len):
    npy_files = [file for file in os.listdir(directory) if file.endswith('.npy')]
    npy_files.sort()  # Sort the files for consistent order

    if len(npy_files) == 0:
        raise ValueError(f"No npy files found in directory '{directory}'")
    loaded_data = []
    labels = []

    for npy_file in npy_files:
        npy_path = os.path.join(directory, npy_file)
        data = np.load(npy_path)

        #trim the data array to the desired shape (min_song_len)
        if len(data[1]) > min_song_len:
            trimmed_data = data[:, :min_song_len]
            loaded_data.append(trimmed_data)
        else:
            loaded_data.append(data)

        # Extract label from the file name by splitting on underscore
        label = npy_file.split('.')[0]
        labels.append(label)
            
    return np.array(loaded_data), labels

directory = new_folder_path
min_song_len = 100  # replace with your value

# Loading all songs
X, y = load_npy_files(directory = directory, min_song_len=min_song_len)

X = (np.rint(X)).astype(int)
labels = np.unique(y)

print("There are " + str(len(labels)) + " labels: " + str(labels))
# Out:
# There are 10 labels: ['blues' 'classical' 'country' 'disco' 'hiphop' 'jazz' 'metal' 'pop'
#  'reggae' 'rock']

# %%
# Defining the number of folds (tunable perameter)
n_folds = 5

# Creating a KFold object
kf = KFold(n_splits=n_folds)

train_results = []
test_results = []

y = np.array(y)  # Convert list to NumPy array

# Iterate over each fold
for train_index, test_index in kf.split(X):
    # Split the data into training and testing sets for this fold
    X_train, X_test = X[train_index], X[test_index]
    y_train, y_test = y[train_index], y[test_index]

# %%
'''
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.33, random_state=7)

labels = np.unique(y_train)
dmin = [np.min(X_train[i]) for i in range(X_train.shape[0])]
dmax = [np.max(X_train[i]) for i in range(X_train.shape[0])]

print(labels)

'''
# Out:
# ['blues' 'classical' 'country' 'disco' 'hiphop' 'jazz' 'metal' 'pop'
#  'reggae' 'rock']

# %% [markdown]
# # selecting sample scale
# for i in range(len(X_train)):
#     # mel region (20 total) corresponds to id
#     for j in range(len(X_train[i])):
#         # time bin selection
#         for k in range(len(X_train[i][j])):
#             if X_train[i][j][k] != 0:
#                 spike = neuro.Spike(id=j,time=0,value=X_train[i][j][k])
#                 proc ....

# %%
risp_config = {
  "leak_mode": True,
  "min_weight": -1,
  "max_weight": 1,
  "min_threshold": -1,
  "max_threshold": 1,
  "max_delay": 5
}


proc = risp.Processor(risp_config)

temp_net = neuro.Network()
temp_net.set_properties(proc.get_network_properties())

# %%
def create_neuron(neuron_id, net, moa):
    neuron = net.add_node(neuron_id)
    temp_net.randomize_node_properties(moa, neuron)
    return neuron

# %%
n_inputs = num_mels
n_hidden = 200
n_outputs = len(labels)
n_neurons = n_inputs+n_hidden+n_outputs
n_synapses = 1200
seed = 42

moa = neuro.MOA()
moa.seed(seed)
random.seed(seed)

# %%
for i in range(n_inputs):
    neuron = create_neuron(i, temp_net, moa)
    neuron.set("Threshold",0.75)
    temp_net.add_input(neuron.id)
    
for i in range(n_outputs):
    neuron = create_neuron(i+n_inputs, temp_net, moa)
    neuron.set("Threshold",0.75)
    temp_net.add_output(neuron.id)
    
for i in range(n_hidden):
    neuron = create_neuron(i+n_inputs+n_outputs, temp_net, moa)

# %%
for i in range(n_synapses):
    source = random.randint(0,n_neurons-1)
    dest = random.randint(0,n_neurons-1)
    synapse = temp_net.add_or_get_edge(source, dest)
    temp_net.randomize_edge_properties(moa, synapse)

# %%
evolver = eons.EONS(eo_params)
evolver.set_template_network(temp_net)

pop = evolver.generate_population(eo_params,1)

# %%
def get_prediction(x):
    #print(x)
    #proc.clear_activity()
    for j in range(len(x)):
            # time bin selection 
            for k in range(len(x[j])): 
                if x[j][k] != 0:
                    spike = neuro.Spike(id=j,time=k,value=x[j][k])
                    #spike = neuro.Spike(id=j,time=0,value=x[j][k])
                    proc.apply_spike(spike)
    proc.run(10000)
    return labels[proc.output_count_max(n_outputs)[0]]

# %%
def fitness(net, X, y):
    proc.load_network(net)
    
    # Set up output tracking
    for i in range(n_outputs):
        proc.track_neuron_events(i)
    
    y_predict = [get_prediction(x) for x in X]
    #print(len(y_predict))
    return accuracy_score(y_predict, y)

# %%
vals = []
for i in range(50):
    # Calculate the fitnesses of all of the networks in the population
    fitnesses = [fitness(net.network, X_train, y_train) for net in pop.networks]
    # Track the best performing network throughout and print the current best result
    max_fit = max(fitnesses)
    mean_fit = np.mean(fitnesses)
    #print(fitnesses)
    vals.append(max_fit)
    print("Epoch ", i, " : ","max fit", max_fit, "mean fit",mean_fit)
    
    # Create the next population based on the fitnesses of the current population
    pop = evolver.do_epoch(pop, fitnesses, eo_params)
# Out:
# Epoch  0  :  max fit 0.18875 mean fit 0.18128749999999996
# Epoch  1  :  max fit 0.18875 mean fit 0.17982499999999998
# Epoch  2  :  max fit 0.18875 mean fit 0.17793749999999997
# Epoch  3  :  max fit 0.18875 mean fit 0.17749999999999996
# Epoch  4  :  max fit 0.18875 mean fit 0.18053749999999993
# Epoch  5  :  max fit 0.19 mean fit 0.17871249999999997
# Epoch  6  :  max fit 0.19 mean fit 0.17971250000000003
# Epoch  7  :  max fit 0.195 mean fit 0.17828749999999996
# Epoch  8  :  max fit 0.195 mean fit 0.18012499999999998
# Epoch  9  :  max fit 0.195 mean fit 0.18085
# Epoch  10  :  max fit 0.195 mean fit 0.1825375
# Epoch  11  :  max fit 0.195 mean fit 0.18427500000000005
# Epoch  12  :  max fit 0.195 mean fit 0.18345
# Epoch  13  :  max fit 0.19625 mean fit 0.18377500000000005
# Epoch  14  :  max fit 0.19625 mean fit 0.18257500000000004
# Epoch  15  :  max fit 0.19625 mean fit 0.18362500000000004
# Epoch  16  :  max fit 0.19625 mean fit 0.18519999999999995
# Epoch  17  :  max fit 0.19625 mean fit 0.183725

# %%
best_net = pop.networks[fitnesses.index(max_fit)].network
train = fitness(best_net, X_train, y_train)
print("Training Accuracy: ", train)
test = fitness(best_net, X_test, y_test)
print("Testing Accuracy: ", test)

# Store the results
train_results.append(train)
test_results.append(test)
# Out:
# Training Accuracy:  0.1775
# Testing Accuracy:  0.0

# %% [markdown]
# 10 Genre Classifier with K-Fold Cross Classifier
